# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos:**
#
# * Listar lenguajes populares para Ciencia de Datos.
# * Identificar algunas de las bibliotecas de Ciencia de Datos más utilizadas.
# * Crear una tabla de herramientas de código abierto para el desarrollo en Ciencia de Datos.
# * Evaluar expresiones aritméticas básicas en celdas de código Python.
# * Convertir unidades de medida utilizando expresiones simples

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# | -------------------------------- |
# | Jupyter Notebooks                |
# | RStudio                          |
# | Apache Spark                     |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python.

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros.
(3*4)+5
# Out:
# 17

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Albert.O
